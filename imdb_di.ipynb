# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
print(len(movies),len(movies.columns))
# Out:
# 979 6

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
sum(movies.duration)/len(movies.duration)
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies[(movies.duration==max(movies.duration)) | (movies.duration==min(movies.duration))]
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 389  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.duration.plot.hist(bins=37);

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies.duration.plot(kind='box');

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.groupby(by="content_rating").title.count()
# Out:
# content_rating
# APPROVED      47
# G             32
# GP             3
# NC-17          7
# NOT RATED     65
# PASSED         7
# PG           123
# PG-13        189
# R            460
# TV-MA          1
# UNRATED       38
# X              4
# Name: title, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.groupby(by="content_rating").title.count().plot(kind="bar",title="# per Content",x="Content",y="#");
plt.xlabel('Content')
plt.ylabel('#');

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
movies['content_raiting']=movies['content_rating'].replace(['NOT RATED','APPROVED','PASSED','GP'],'UNRATED')
movies['content_raiting'].head(10)
# Out:
# 0          R
# 1          R
# 2          R
# 3      PG-13
# 4          R
# 5    UNRATED
# 6    UNRATED
# 7      PG-13
# 8          R
# 9          R
# Name: content_raiting, dtype: object

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies['content_raiting']=movies['content_raiting'].replace(['X','TV-MA'],'NC-17')
movies['content_raiting']
# Out:
# 0            R
# 1            R
# 2            R
# 3        PG-13
# 4            R
# 5      UNRATED
# 6      UNRATED
# 7        PG-13
# 8            R
# 9            R
# 10       PG-13
# 11       PG-13
# 12          PG
# 13       PG-13
# 14       PG-13
# 15       PG-13
# 16           R
# 17     UNRATED
# 18           R
# 19          PG
# 20           R
# 21           R
# 22     UNRATED
# 23           R
# 24           R
# 25       PG-13
# 26       PG-13
# 27           R
# 28           R
# 29     UNRATED
#         ...
# 949         PG
# 950          R
# 951          R
# 952          R
# 953         PG
# 954      PG-13
# 955          R
# 956         PG
# 957          R
# 958      PG-13
# 959          R
# 960      PG-13
# 961          R
# 962         PG
# 963          R
# 964      PG-13
# 965      PG-13
# 966      PG-13
# 967          R
# 968          R
# 969          R
# 970          R
# 971          R
# 972      NC-17
# 973      PG-13
# 974         PG
# 975         PG
# 976      PG-13
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.isnull().sum()
# Out:
# star_rating        0
# title              0
# content_rating     3
# genre              0
# duration           0
# actors_list        0
# content_raiting    3
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies[movies.content_raiting.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list  \
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
#
#     content_raiting
# 187             NaN
# 649             NaN
# 936             NaN

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
movies[movies['duration']>=120]['star_rating'].mean(skipna=True),movies[movies['duration']<120]['star_rating'].mean(skipna=True)
# Out:
# (7.948898678414082, 7.838666666666657)

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
movies.plot(kind='scatter',x='duration',y='star_rating');
#Doesn't seam to be a relationship (at least linear), the values are too scatter

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.hist(column='duration',by='content_raiting',sharex=True,sharey=True,figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5553336898>,
# ...
#       dtype=object)

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.groupby('genre')['title','star_rating'].max()
# Out:
#                                          title  star_rating
# genre
# Action                                 Yojimbo          9.0
# Adventure                            True Grit          8.9
# Animation                       Wreck-It Ralph          8.6
# Biography                        Walk the Line          8.9
# Comedy                              Zombieland          8.6
# Crime                                   Zodiac          9.3
# Drama                                     Zulu          8.9
# Family     Willy Wonka & the Chocolate Factory          7.9
# Fantasy              The City of Lost Children          7.7
# Film-Noir                        The Third Man          8.3
# History                    Battleship Potemkin          8.0
# Horror                                   [Rec]          8.6
# Mystery                                Vertigo          8.6
# Sci-Fi           The Day the Earth Stood Still          8.2
# Thriller             The Man Who Knew Too Much          8.0
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
movies[movies.duplicated('title')]
# Out:
#      star_rating                            title content_rating      genre  \
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list  \
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 924       134  [u'Liam Neeson', u'Geoffrey Rush', u'Uma Thurm...
# 936       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']
#
#     content_raiting
# 482               R
# 905               R
# 924           PG-13
# 936             NaN

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
genre_bool=pd.DataFrame(movies.groupby('genre')['title'].count()>10)
rel_genre=genre_bool[genre_bool['title']==True].reset_index()['genre'].tolist()

movies[movies['genre'].isin(rel_genre)]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# ...

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
